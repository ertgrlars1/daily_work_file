# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
#1
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200, 56000, 62316, 64928, 67317, 68748, 73752]
salary_2 = [45372, 48876, 53850, 57287, 63016, 65998, 70003, 70000, 71496, 75370, 83640]

# %%
plt.figure(figsize = (6, 3))
plt.plot(age, salary, label = "salary", ls = '--', marker = "*", markersize = 5)
plt.plot(age, salary_2, label = "salary_2", ls = '-.', lw = 1, marker = "*", markersize = 5)

plt.xlabel("Age")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
from matplotlib import style

# %%
#2
x = np.arange(0,30,0.2)
y = np.sin(x)

# %%
style.use("ggplot")
# tüm temayı kırmızı yaptı
plt.plot(x, y);

# %%
style.use("fivethirtyeight")
plt.plot(x, y);

# %% [markdown]
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
style.use("dark_background")
plt.plot(x, y);

# %%
style.use("grayscale")
plt.plot(x, y);

# %%
style.use("grayscale")
plt.grid(False)
plt.plot(x, y);

# %%
plt.title("Sin Functions")
style.use("classic")
plt.plot(x, y);

# %%
plt.title("Sin Functions")
plt.suptitle("I am Bigger")
plt.grid(True)
plt.xlabel("Number")
plt.ylabel("Sinüs")
style.use("classic")
plt.plot(x, y);

# %%
y1 = np.sin(x)
y2 = np.cos(x)

# %%
plt.plot(x, y2, label = "Cos")
plt.plot(x, y1, label = "Sin")
plt.legend(loc = "upper left")

# %%
#3
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
fig, ax = plt.subplots(figsize = (6, 3))

ax.bar(tips.day, tips.total_bill, label = "total_bill")
ax.bar(tips.day, tips.tip, label = "tip")
plt.legend();

# %%
#4
company = ["GOOGL", "AMZN", "MSFT", "FB"]
revenue = [90, 136, 89, 27]
xpos = np.arange(len(company))

# %%
plt.bar(xpos, revenue);

# %%
plt.xticks(xpos, company)
plt.xlabel("revenue(bln)")
plt.title("Us Tech Stocks")
plt.bar(xpos, revenue);

# %%
plt.xticks(xpos, company)
plt.xlabel("revenue(bln)")
plt.title("Us Tech Stocks")
plt.bar(xpos, revenue, label = "Revenue")
plt.legend();

# %%
profit = [40, 2, 34, 12]

# %%
plt.xticks(xpos, company)
plt.xlabel("revenue(bln)")
plt.title("Us Tech Stocks")
plt.bar(xpos, revenue, label = "Revenue")
plt.bar(xpos, profit, label = "Profit")
plt.legend();

# %%
plt.xticks(xpos, company)
plt.xlabel("revenue(bln)")
plt.title("Us Tech Stocks")
plt.bar(xpos -0.2, revenue, label = "Revenue")
plt.bar(xpos + 0.2, profit, label = "Profit")
plt.legend();

# %%
plt.xticks(xpos, company)
plt.xlabel("revenue(bln)")
plt.title("Us Tech Stocks")
plt.bar(xpos -0.2, revenue, width = 0.4, label = "Revenue")
plt.bar(xpos + 0.2, profit, width = 0.4, label = "Profit")
plt.legend();

# %%
plt.yticks(xpos, company)
plt.title("Us Tech Stocks")
plt.barh(xpos - 0.2, revenue, label = "Revenue")
plt.barh(xpos + 0.2, profit, label = "Profit")
plt.legend();

# %%
plt.yticks(xpos, company)
plt.title("Us Tech Stocks")
plt.barh(xpos - 0.2, revenue, height=0.4, label = "Revenue")
plt.barh(xpos + 0.2, profit, height=0.4, label = "Profit")
plt.legend();

# %%
#5
plt.hist(tips.total_bill, bins = 30);

# %%
#6
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]

# %%
plt.hist(blood_sugar)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(blood_sugar, bins = 3)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, bins = 3, rwidth = 0.97)
# Out:
# (array([7., 2., 4.]),
#  array([ 77.        , 101.33333333, 125.66666667, 150.        ]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, bins = [80,100,125, 150], rwidth = 0.97)
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, bins = [80,100,125, 150], rwidth = 0.97, color = "g")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  <BarContainer object of 3 artists>)

# %%
plt.hist(blood_sugar, bins = [80,100,125, 150], rwidth = 0.97, color = "g", histtype = "step")
# Out:
# (array([6., 2., 4.]),
#  array([ 80, 100, 125, 150]),
#  [<matplotlib.patches.Polygon at 0x1d1b7f9a530>])

# %%
blood_sugar_men =  [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar range")
plt.ylabel("Total no of patiens")
plt.title("Blood sugar analysis")
plt.hist([blood_sugar_men, blood_sugar_women], bins = [80,100,125, 150], rwidth = 0.97, color = ["g", "b"], label = ["men", "women"])
plt.legend();

# %%
blood_sugar_men =  [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]

plt.xlabel("Sugar range")
plt.ylabel("Total no of patiens")
plt.title("Blood sugar analysis")
plt.hist([blood_sugar_men, blood_sugar_women], bins = [80,100,125, 150], rwidth = 0.97, color = ["g", "b"],
         label = ["men", "women"], orientation="horizontal")
plt.legend();

# %%
#7
x = np.random.normal(170, 10, 250)

plt.boxplot(x);

# %%
plt.figure(figsize=(7,7))

y = np.array([35, 25, 25, 15])

mylabels = ["Apples", "Bananas", "Chrerries", "Dates"]
myexplode = [0.1, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, labeldistance=None, autopct = "%.1f")
plt.legend();

# %%
#8
exp_vals = [1400, 600, 300, 410, 250]
exp_labels = ["Home Rent", "Food", "Phone/Internet Bill", "Car", "Other Utilities"]

# %%
plt.pie(exp_vals, labels = exp_labels);

# %%
plt.pie(exp_vals, labels = exp_labels, radius=0.5);

# %%
plt.pie(exp_vals, labels = exp_labels, autopct="%.2f");

# %%
plt.pie(exp_vals, labels = exp_labels, autopct="%.2f", shadow=True);

# %%
plt.pie(exp_vals, labels = exp_labels, autopct="%.2f", explode = [0.08, 0, 0, 0, 0]);

# %%
plt.pie(exp_vals, labels = exp_labels, autopct="%.2f", explode = [0.08, 0, 0, 0, 0], startangle=90);

# %%
plt.pie(exp_vals, labels = exp_labels, autopct="%.2f", explode = [0.08, 0, 0, 0, 0], startangle=45);

# %%
plt.pie(exp_vals, labels = exp_labels, autopct="%.2f", explode = [0.08, 0, 0, 0, 0], startangle=180);

# %%
plt.pie(exp_vals, labels = exp_labels, labeldistance=None, autopct="%.2f", explode = [0.08, 0, 0, 0, 0], startangle=180)
plt.legend(loc = "lower right");
