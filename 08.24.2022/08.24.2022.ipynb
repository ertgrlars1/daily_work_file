# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams['figure.dpi'] = 70
import warnings
warnings.filterwarnings("ignore")

# %%
#1
df = sns.load_dataset("tips")

# %%
sns.scatterplot(x = "total_bill", y = "tip", data = df, hue = "day", s = 200, style = "day");

# %% [markdown]
# ## Seaborn : scatterplot

# %%
#2
diamonds = sns.load_dataset("diamonds")
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds = diamonds[diamonds.cut.isin(["Premium", "Good"]) &
                    diamonds.color.isin(["D", "F", "J"])].sample(n = 100, random_state = 22)

# %% [markdown]
# ## Basics

# %%
sns.set_style("dark")

# %%
sns.scatterplot(diamonds.carat, diamonds.price);
#sns.scatterplot(x = "carat", y = "price", data = diamonds)

# %%
sns.scatterplot(x = "x", y = "y", data = diamonds);

# %% [markdown]
# ## Semantic Variables

# %%
sns.set_style("darkgrid")

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds);

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, hue="cut");

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette = ['purple', '#55CCCC'],
                hue_order=['Good', 'Premium']
               );

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, hue="cut", palette=["purple", "red", "aqua", "white", "black"]);

# %% [markdown]
# ## Continuous Variable

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, hue="depth");

# %% [markdown]
# ## style

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, s = 100);

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, s = 100, style="cut");

# %% [markdown]
# ## Style Order

# %%
sns.scatterplot(x='carat', y='price', style='cut',
                data=diamonds,
                style_order=['Good', 'Premium']
       );

# %% [markdown]
# ## size

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="cut");

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="cut", sizes=[0,150, 0, 10, 0]);

# %% [markdown]
# ## Size Order

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="cut", size_order=["Premium", "Good"]);

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="cut", size_order=["Premium", "Good"], sizes = [10,100]);

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="depth");

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="depth");

# %% [markdown]
# ## Legend

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, size="depth", legend = "full");
# default = "brief"

# %% [markdown]
# ## hue + style + size

# %%
sns.scatterplot(x = "carat", y = "price", hue = "cut", style = "cut", data = diamonds, s = 100);

# %%
sns.scatterplot(x = "carat", y = "price", hue = "cut", style = "color", data = diamonds, s = 100);

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                size='depth',
                data=diamonds);

# %% [markdown]
# ## Additional Styling

# %% [markdown]
# ## alpha

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, s = 100, alpha=0.6);

# %% [markdown]
# ## marker styling

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, s = 200, marker = "*");

# %%
sns.scatterplot(x = "carat", y = "price", data = diamonds, s = 200, marker = "*", edgecolor =  "black");

# %%
#3
sns.histplot(data = df, x = "total_bill", kde = True);

# %%
#4
penguins = sns.load_dataset("penguins")
penguins.dropna(inplace = True)
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %% [markdown]
# ## Intro Visuals

# %% [markdown]
# distplot has now been deprecated. Switch to histplot for histogram plots.

# %%
sns.distplot(penguins.flipper_length_mm);

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(penguins.bill_length_mm);
# sns.histplot(x = "bill_length_mm", data = penguins)

# %%
sns.histplot(y = "bill_length_mm", data = penguins);

# %% [markdown]
# ## kde

# %%
sns.histplot(x = "bill_length_mm", data = penguins, kde = True);

# %% [markdown]
# ## bins

# %%
sns.histplot(x = "bill_length_mm", data = penguins, bins = 20);

# %%
sns.histplot(x = "bill_length_mm", data = penguins, bins = [30, 40, 45, 50, 60]);

# %% [markdown]
# ## binwidth and binrange

# %%
sns.histplot(x = "bill_length_mm", data = penguins, binwidth=10);
# kutu 10 birim genişliğinde

# %%
sns.histplot(x = "bill_length_mm", data = penguins, binwidth=10, binrange=(30, 60));
# 30 ile 60 aralıgında 10 birim uzunluklu

# %% [markdown]
# # Statistics

# %% [markdown]
# ## stat

# %%
sns.histplot(x='bill_length_mm', data=penguins,
             stat='count'
            );
# default count

# %% [markdown]
# <b>density</b> - AREA of histogram sums to one

# %%
sns.histplot(x = "bill_length_mm", data = penguins, stat="density");
# yogunluguna baktık
# cubukların yukseklıgı * uzunlugu, hepsinin toplamı bize 1'i verir

# %% [markdown]
# <b>probability</b> - HEIGHT of histogram bars to one

# %%
sns.histplot(x = "bill_length_mm", data = penguins, stat="probability");
# olasılıkları, cubukların yukseklıkleri bize 1i verir

# %% [markdown]
# ## cumulative

# %%
sns.histplot(x='bill_length_mm', data=penguins,
             stat='probability', fill=False, element='step',
             cumulative=True
            );

# %% [markdown]
# # Categorical Variables

# %% [markdown]
# ## hue

# %%
sns.histplot(x='bill_length_mm', data=penguins, hue='species');

# %% [markdown]
# ## element

# %%
sns.histplot(x = "bill_length_mm", data = penguins, hue = "species", element = "step");

# %%
sns.histplot(x = "bill_length_mm", data = penguins, hue = "species", element = "poly");

# %% [markdown]
# ## multiple

# %%
sns.histplot(x = "bill_length_mm", data = penguins, hue = "species", multiple = "layer");

# %%
sns.histplot(x = "bill_length_mm", data = penguins, hue = "species", multiple = "stack");
# stack ile üst üste istifledi

# %%
sns.histplot(x = "bill_length_mm", data = penguins, hue = "species", multiple = "fill");
# her sutunun 0 ile 1 arasındaki oranını soyler

# %%
sns.histplot(x = "species", data = penguins, hue = "island", multiple = "dodge");

# %% [markdown]
# # Bivariate Histplot

# %%
sns.set_style('white')

# %%
sns.histplot(x = "bill_length_mm", y = "bill_depth_mm", data = penguins);

# %% [markdown]
# ## cbar

# %%
sns.histplot(x = "bill_length_mm", y = "bill_depth_mm", data = penguins, cbar = True);
# renkerin ne anlama geldıgını ogrendık

# %% [markdown]
# # hue

# %%
sns.histplot(x = "bill_length_mm", y = "bill_depth_mm", data = penguins, hue="species");

# %% [markdown]
# ## Discrete color map

# %%
sns.histplot(x = "bill_length_mm", y = "species", data = penguins, hue="species");

# %% [markdown]
# # Styling

# %% [markdown]
# ## shrink

# %%
sns.histplot(x = "species", shrink=0.8, hue = "sex", multiple = "dodge", data = penguins);
# sutunların arsını acar

# %% [markdown]
# ## color, palette

# %%
sns.histplot(x = "bill_length_mm", data = penguins, color = "indigo");

# %%
sns.histplot(x = "species", shrink=0.8, hue = "sex", multiple = "dodge", data = penguins, palette="bone");

# %% [markdown]
# ## fill

# %%
sns.histplot(x = "bill_length_mm", data = penguins, stat="probability", fill=False);
# içini boşalltı

# %%
sns.histplot(x = "bill_length_mm", data = penguins, stat="probability", fill=False, element="step", cumulative=True);
# x ekseni boyunca eklenerek olasılıkların nasıl oldugunu gosterir

# %%
sns.histplot(x = "bill_length_mm", data = penguins, stat="probability", fill=False, element="step");

# %%
sns.histplot(x = "bill_length_mm", data = penguins, fill = False);

# %%
#5
sns.displot(x = "total_bill", data = df, kde = True);

# %%
#6
cars = sns.load_dataset("mpg").dropna()
cars.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # Basics

# %%
sns.displot(x='weight', data=cars);
# kind = hist defaut

# %% [markdown]
# ## kde

# %%
sns.displot(x = "weight", data = cars, kde = True);

# %% [markdown]
# ## kind

# %%
sns.displot(x = "weight", data = cars, kind = "kde");

# %% [markdown]
# ## ecdf

# %%
sns.displot(x = "weight", data = cars, kind = "ecdf");
# kümülatif olarak degerlerin oranını soyluyor

# %% [markdown]
# ## rug

# %%
sns.displot(x = "weight", data = cars, rug = True, kind = "kde");

# %% [markdown]
# ## Categorical Variables: hue

# %%
sns.displot(x = "weight", data = cars, hue = "origin");

# %%
sns.displot(x = "weight", data = cars, kind = "kde", hue = "origin");

# %% [markdown]
# ## Bivariate (2D) Options

# %%
sns.displot(x = "weight",y = "horsepower", data = cars);

# %%
sns.displot(x = "weight",y = "horsepower", data = cars, kind = "kde");

# %%
sns.displot(x = "weight",y = "horsepower", data = cars, kind = "kde", rug = True);

# %% [markdown]
# # Small Multiples (FacetGrid)

# %% [markdown]
# ## rown and col

# %%
sns.displot(x = "weight", data = cars, hue = "origin", col =  "origin");

# %%
sns.displot(x = "weight", data = cars, hue = "origin", col =  "origin", kind = "kde", rug = True);

# %%
sns.displot(x = "weight", 
            data = cars[cars.cylinders.isin([4, 6, 8])], 
            hue = "cylinders", 
            col =  "origin", 
            row = "cylinders");

# %% [markdown]
# # Styling

# %% [markdown]
# ## palette

# %%
sns.displot(x = "weight", 
            data = cars[cars.cylinders.isin([4, 6, 8])], 
            hue = "cylinders", 
            col =  "origin", 
            row = "cylinders",
            palette = ["red", "blue", "purple"]);

# %%
sns.displot(x = "weight", data = cars, hue = "origin", col = "origin", palette = "crest");

# %% [markdown]
# ## height, aspect

# %%
sns.displot(x = "weight", data = cars, hue = "origin", col = "origin");

# %%
sns.displot(x = "weight", data = cars, col = "origin", height = 2);

# %%
sns.displot(x = "weight", data = cars, col = "origin", height = 5);

# %%
sns.displot(x = "weight", data = cars, col = "origin", height = 2, aspect = 1.5);
# default aspect = 1

# %% [markdown]
# ## weight

# %%
sns.displot(x = "weight", data = cars);

# %%
sns.displot(x = "weight", data = cars, weights=10);
# y eksenini çarptı

# %% [markdown]
# # Other Keywords: Plot Specific

# %%
sns.displot(x = "weight", data = cars, bins = 10);

# %%
sns.displot(x = "weight", data = cars, kind = "kde", fill = True, lw = 5);

# %% [markdown]
# ## rug_kws

# %%
sns.displot(x = "weight", data = cars, kind = "kde", rug = True, rug_kws = {"height" : 0.1});

# %% [markdown]
# # FacetGrid Styling

# %% [markdown]
# ## facet_kws

# %%
g = sns.displot(x = "weight", data = cars, col = "origin");

# %%
sns.displot(x = "weight", data = cars, col = "origin", facet_kws = {"despine" : False});

# %% [markdown]
# # FacetGrid Object

# %%
g.axes_dict.items()
# Out:
# dict_items([('usa', <AxesSubplot:title={'center':'origin = usa'}, xlabel='weight', ylabel='Count'>), ('japan', <AxesSubplot:title={'center':'origin = japan'}, xlabel='weight'>), ('europe', <AxesSubplot:title={'center':'origin = europe'}, xlabel='weight'>)])

# %%
g = sns.displot(x='weight', data=cars, col='origin')

for col_val, ax in g.axes_dict.items():
    if col_val == "europe":
        ax.set_facecolor("#E2F2FF")

# %%
#7
sns.kdeplot(x = "total_bill", data = df);

# %% [markdown]
# # Univariate (1D)

# %%
#8
sns.kdeplot(cars.horsepower);

# %% [markdown]
# ## shade

# %%
sns.kdeplot(cars.horsepower, shade=True);
# gölgeleme

# %% [markdown]
# ## bw_adjust

# %%
sns.kdeplot(cars.horsepower, bw_adjust=  0.1);
# pürüzsüzleştirme

# %%
sns.kdeplot(cars.horsepower, bw = 0.8);

# %% [markdown]
# ## cumulative

# %%
sns.kdeplot(cars.horsepower, cumulative=True);

# %% [markdown]
# # Bivariate (2D)

# %%
sns.kdeplot(cars.horsepower, cars.mpg);

# %% [markdown]
# ## n_levels & shade

# %%
sns.kdeplot(cars.horsepower, cars.mpg, n_levels = 20);

# %%
sns.kdeplot(cars.horsepower, cars.mpg, shade = True);
# en dusuk yogunluk acık mavi koyular yüksek yogunluk

# %% [markdown]
# ## shade_lowest

# %%
sns.kdeplot(cars.horsepower, cars.mpg, shade = True, shade_lowest=True);

# %% [markdown]
# ## cbar

# %%
sns.kdeplot(cars.horsepower, cars.mpg, shade = True, cbar = True);

# %% [markdown]
# # Bivariate KDEplot by Category

# %%
sns.set_style('whitegrid')

cyl_4 = cars[cars.cylinders==4]
cyl_8 = cars[cars.cylinders==8]

plt.figure(figsize=(8,6))

sns.kdeplot(cyl_4.horsepower, cyl_4.mpg,
            cmap="Blues", shade=True, shade_lowest=False)
sns.kdeplot(cyl_8.horsepower, cyl_8.mpg,
            cmap="Reds", shade=True, shade_lowest=False)

plt.xlabel('Horsepower', fontsize=14)
plt.ylabel('Miles per Gallon (MPG)', fontsize=14)

plt.annotate("4 Cylinders", (105, 32), color="blue", fontsize=16, fontweight='bold')
plt.annotate("8 Cylinders", (190, 18), color="red", fontsize=16, fontweight='bold');
