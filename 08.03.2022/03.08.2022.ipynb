# %%
#1

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
titanic_df = pd.read_excel('titanic3.xls', 'titanic3', index_col=None,na_values=['NA'])

# %%
titanic_df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
titanic_df.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
titanic_df.drop(['ticket', 'cabin', 'boat', 'body'], axis = 1).head()
# Girilen satırları veriden çıkardık
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch      fare embarked                        home.dest
# 0  29.0000      0      0  211.3375        S                     St Louis, MO
# 1   0.9167      1      2  151.5500        S  Montreal, PQ / Chesterville, ON
# 2   2.0000      1      2  151.5500        S  Montreal, PQ / Chesterville, ON
# 3  30.0000      1      2  151.5500        S  Montreal, PQ / Chesterville, ON
# 4  25.0000      1      2  151.5500        S  Montreal, PQ / Chesterville, ON

# %%
pd.value_counts(titanic_df['survived']).plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic_df['survived'].mean()
# Out:
# 0.3819709702062643

# %%
titanic_df.groupby(['sex']).mean()
# Out:
#           pclass  survived        age     sibsp     parch       fare  \
# sex
# female  2.154506  0.727468  28.687071  0.652361  0.633047  46.198097
# male    2.372479  0.190985  30.585233  0.413998  0.247924  26.154601
#
#              body
# sex
# female  166.62500
# male    160.39823

# %%
titanic_df.groupby(['sex', 'pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare        body
# sex    pclass
# female 1       0.965278  37.037594  0.555556  0.472222  109.412385         NaN
#        2       0.886792  27.499191  0.500000  0.650943   23.234827   52.000000
#        3       0.490741  22.185307  0.791667  0.731481   15.324250  183.000000
# male   1       0.340782  41.029250  0.340782  0.279330   69.888385  162.828571
#        2       0.146199  30.815401  0.327485  0.192982   19.904946  171.233333
#        3       0.152130  25.962273  0.470588  0.255578   12.415462  151.854167

# %%
titanic_df[titanic_df['age'] < 18].groupby(['sex','pclass']).mean()
# Out:
#                survived        age     sibsp     parch        fare   body
# sex    pclass
# female 1       0.875000  14.125000  0.500000  0.875000  104.083337    NaN
#        2       1.000000   8.273150  0.666667  1.166667   27.998844    NaN
#        3       0.543478   8.416667  1.456522  1.043478   18.284148  328.0
# male   1       0.857143   9.845243  0.571429  1.714286  129.752371    NaN
#        2       0.733333   6.222220  0.600000  0.933333   31.750280    NaN
#        3       0.233333   9.838888  1.966667  1.016667   21.677570   65.5

# %%
#2
import pandas as pd

# %%
series = pd.Series(('Ertu', 'A', 27, 'ertgrlars1@gmail.com', 179))
series
# Out:
# 0                    Ertu
# 1                       A
# 2                      27
# 3    ertgrlars1@gmail.com
# 4                     179
# dtype: object

# %%
dataframe1 = pd.DataFrame([('Ertug', 'A', 27, 'ertgrlars1@gmail.com', 179),
                           ('Levent', 'A',50, 'leventarslan@gmal.com', 165 )],
                          columns = ['First Name', 'Last Name', 'Age', 'e-mail', 'Wight' ])

# %%
dataframe1
# Out:
#   First Name Last Name  Age                 e-mail  Wight
# 0      Ertug         A   27   ertgrlars1@gmail.com    179
# 1     Levent         A   50  leventarslan@gmal.com    165

# %%
dataframe2 = pd.DataFrame({'First Name' : ['Ertug', 'Levent'],
                           'Last Name': ['A', 'A'],
                           'Age' : [27, 50],
                           'e-mail' : ['ertgrlars1@gmail.com', 'leventarslan@gmal.com'],
                           'Weight' : [179, 165]})
# dict yöntemi ile

# %%
dataframe2
# Out:
#   First Name Last Name  Age                 e-mail  Weight
# 0      Ertug         A   27   ertgrlars1@gmail.com     179
# 1     Levent         A   50  leventarslan@gmal.com     165

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv')

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.shape
# Out:
# (76, 9)

# %%
df.tail()
#son 5
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
#3
ser = pd.Series(list('Clarusway'))
ser
# Out:
# 0    C
# 1    l
# 2    a
# 3    r
# 4    u
# 5    s
# 6    w
# 7    a
# 8    y
# dtype: object

# %%
ser.sort_index(ascending=False)
# Out:
# 8    y
# 7    a
# 6    w
# 5    s
# 4    u
# 3    r
# 2    a
# 1    l
# 0    C
# dtype: object

# %%
ser.sort_values()
# Out:
# 0    C
# 2    a
# 7    a
# 1    l
# 3    r
# 5    s
# 4    u
# 6    w
# 8    y
# dtype: object

# %%
ser.isin(['a'])
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# dtype: bool

# %%
ser.keys()
# Out:
# RangeIndex(start=0, stop=9, step=1)

# %%
ser.values
# Out:
# array(['C', 'l', 'a', 'r', 'u', 's', 'w', 'a', 'y'], dtype=object)

# %%
ser.items()

# %%
list(ser.items())
# Out:
# [(0, 'C'),
#  (1, 'l'),
#  (2, 'a'),
#  (3, 'r'),
#  (4, 'u'),
#  (5, 's'),
#  (6, 'w'),
#  (7, 'a'),
#  (8, 'y')]

# %%
dataframe=pd.read_csv('my_file.csv')

# %%
df = pd.DataFrame(np.arange(1, 24, 2).reshape(3, 4),
                  columns = ['var1', 'var2', 'var3', 'var4'])

# %%
df
# Out:
#    var1  var2  var3  var4
# 0     1     3     5     7
# 1     9    11    13    15
# 2    17    19    21    23

# %%
df.head(1)
# Out:
#    var1  var2  var3  var4
# 0     1     3     5     7

# %%
df.tail(1)
# Out:
#    var1  var2  var3  var4
# 2    17    19    21    23

# %%
df.sample(n = 2)
# Out:
#    var1  var2  var3  var4
# 2    17    19    21    23
# 0     1     3     5     7

# %%
df.shape
# Out:
# (3, 4)

# %%
# 4
np.random.seed(101)
df = pd.DataFrame(np.random.randint(9, size = (5 , 4)),
             index = 'A B C D E'.split(),
             columns = 'W X Y Z'.split())
df
# Out:
#    W  X  Y  Z
# A  1  6  7  8
# B  4  8  5  0
# C  5  8  1  3
# D  8  3  3  2
# E  8  3  7  0

# %%
df.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E'], dtype='object')

# %%
df.columns
# Out:
# Index(['W', 'X', 'Y', 'Z'], dtype='object')

# %%
df.shape
# Out:
# (5, 4)

# %%
df.size
# Out:
# 20

# %%
df.ndim
# Out:
# 2

# %%
df.reset_index(0)
# Out:
#   index  W  X  Y  Z
# 0     A  1  6  7  8
# 1     B  4  8  5  0
# 2     C  5  8  1  3
# 3     D  8  3  3  2
# 4     E  8  3  7  0

# %%
newindx = 'CA NY WY OR CO'.split()
newindx
# Out:
# ['CA', 'NY', 'WY', 'OR', 'CO']

# %%
df['newindx'] = newindx
df
# Out:
#    W  X  Y  Z newindx
# A  1  6  7  8      CA
# B  4  8  5  0      NY
# C  5  8  1  3      WY
# D  8  3  3  2      OR
# E  8  3  7  0      CO

# %%
df.set_index('newindx')
# Out:
#          W  X  Y  Z
# newindx
# CA       1  6  7  8
# NY       4  8  5  0
# WY       5  8  1  3
# OR       8  3  3  2
# CO       8  3  7  0

# %%
df['W']
# Out:
# A    1
# B    4
# C    5
# D    8
# E    8
# Name: W, dtype: int32

# %%
df.W
# Out:
# A    1
# B    4
# C    5
# D    8
# E    8
# Name: W, dtype: int32

# %%
df.iloc[1, 0]
# Out:
# 4

# %%
df.loc['B', 'W']
# Out:
# 4

# %%
df[df.Y < 6]
# Out:
#    W  X  Y  Z newindx
# B  4  8  5  0      NY
# C  5  8  1  3      WY
# D  8  3  3  2      OR

# %%
#5
df = df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv')

# %%
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.set_index('Major_code').head()
# Out:
#             Rank                                      Major Major_category  \
# Major_code
# 2419           1                      PETROLEUM ENGINEERING    Engineering
# 2416           2             MINING AND MINERAL ENGINEERING    Engineering
# 2415           3                  METALLURGICAL ENGINEERING    Engineering
# 2417           4  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 2418           5                        NUCLEAR ENGINEERING    Engineering
#
#             Total   Men  Women  ShareWomen  Median
# Major_code
# 2419         2339  2057    282    0.120564  110000
# 2416          756   679     77    0.101852   75000
# 2415          856   725    131    0.153037   73000
# 2417         1258  1123    135    0.107313   70000
# 2418         2573  2200    373    0.144967   65000

# %%
df.set_index('Major_code', inplace=True)
# Major code'unu başa getirerek kalıcı hale getirir

# %%
df.Major
# Out:
# 0                             PETROLEUM ENGINEERING
# 1                    MINING AND MINERAL ENGINEERING
# 2                         METALLURGICAL ENGINEERING
# 3         NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               NUCLEAR ENGINEERING
#                           ...
# 71                                          ECOLOGY
# 72                    TREATMENT THERAPY PROFESSIONS
# 73              GENERAL MEDICAL AND HEALTH SERVICES
# 74    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df['Major']
# Out:
# 0                             PETROLEUM ENGINEERING
# 1                    MINING AND MINERAL ENGINEERING
# 2                         METALLURGICAL ENGINEERING
# 3         NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4                               NUCLEAR ENGINEERING
#                           ...
# 71                                          ECOLOGY
# 72                    TREATMENT THERAPY PROFESSIONS
# 73              GENERAL MEDICAL AND HEALTH SERVICES
# 74    COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75                                          ZOOLOGY
# Name: Major, Length: 76, dtype: object

# %%
df.loc[0, 'Major']
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[0]
# Out:
# Rank                                  1
# Major_code                         2419
# Major             PETROLEUM ENGINEERING
# Major_category              Engineering
# Total                              2339
# Men                                2057
# Women                               282
# ShareWomen                     0.120564
# Median                           110000
# Name: 0, dtype: object

# %%
df.iloc[0,2]
# Out:
# 'PETROLEUM ENGINEERING'

# %%
df.iloc[2:10]
# Out:
#    Rank  Major_code                                      Major  \
# 2     3        2415                  METALLURGICAL ENGINEERING
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING
# 4     5        2418                        NUCLEAR ENGINEERING
# 5     6        2405                       CHEMICAL ENGINEERING
# 6     7        5001                 ASTRONOMY AND ASTROPHYSICS
# 7     8        2414                     MECHANICAL ENGINEERING
# 8     9        2401                      AEROSPACE ENGINEERING
# 9    10        2408                     ELECTRICAL ENGINEERING
#
#       Major_category  Total    Men  Women  ShareWomen  Median
# 2        Engineering    856    725    131    0.153037   73000
# 3        Engineering   1258   1123    135    0.107313   70000
# 4        Engineering   2573   2200    373    0.144967   65000
# 5        Engineering  32260  21239  11021    0.341631   65000
# 6  Physical Sciences   1792    832    960    0.535714   62000
# ...

# %%
df.iloc[-5:]
# Out:
#     Rank  Major_code                                          Major  \
# 71    72        3604                                        ECOLOGY
# 72    73        6109                  TREATMENT THERAPY PROFESSIONS
# 73    74        6100            GENERAL MEDICAL AND HEALTH SERVICES
# 74    75        6102  COMMUNICATION DISORDERS SCIENCES AND SERVICES
# 75    76        3609                                        ZOOLOGY
#
#             Major_category  Total    Men  Women  ShareWomen  Median
# 71  Biology & Life Science   9154   3878   5276    0.576360   33000
# 72                  Health  48491  13487  35004    0.721866   33000
# 73                  Health  33599   7574  26025    0.774577   32400
# 74                  Health  38279   1225  37054    0.967998   28000
# 75  Biology & Life Science   8409   3050   5359    0.637293   26000

# %%
df.iloc[2:7, 1:4]
# Out:
#    Major_code                                      Major     Major_category
# 2        2415                  METALLURGICAL ENGINEERING        Engineering
# 3        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING        Engineering
# 4        2418                        NUCLEAR ENGINEERING        Engineering
# 5        2405                       CHEMICAL ENGINEERING        Engineering
# 6        5001                 ASTRONOMY AND ASTROPHYSICS  Physical Sciences

# %%
df['Major'] == 'ECOLOGY'
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 71     True
# 72    False
# 73    False
# 74    False
# 75    False
# Name: Major, Length: 76, dtype: bool

# %%
df[df['Major'] == 'ECOLOGY']
# Out:
#     Rank  Major_code    Major          Major_category  Total   Men  Women  \
# 71    72        3604  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#     ShareWomen  Median
# 71     0.57636   33000

# %%
df.loc[df['Major'] == 'ECOLOGY']
# Out:
#     Rank  Major_code    Major          Major_category  Total   Men  Women  \
# 71    72        3604  ECOLOGY  Biology & Life Science   9154  3878   5276
#
#     ShareWomen  Median
# 71     0.57636   33000

# %%
df[df['ShareWomen'] > 0.5]
# Out:
#     Rank  Major_code                                              Major  \
# 6      7        5001                         ASTRONOMY AND ASTROPHYSICS
# 26    27        6107                                            NURSING
# 28    29        5102  NUCLEAR, INDUSTRIAL RADIOLOGY, AND BIOLOGICAL ...
# 34    35        3702                    STATISTICS AND DECISION SCIENCE
# 35    36        3607                                       PHARMACOLOGY
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 37    38        5006                                       OCEANOGRAPHY
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 42    43        4006                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 47    48        3605                                           GENETICS
# 48    49        3603                                  MOLECULAR BIOLOGY
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# ...

# %%
df[(df['ShareWomen'] > 0.5) & (df['Major_category'] == 'Biology & Life Science')]
# Out:
#     Rank  Major_code                                Major  \
# 35    36        3607                         PHARMACOLOGY
# 42    43        4006  COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 47    48        3605                             GENETICS
# 48    49        3603                    MOLECULAR BIOLOGY
# 51    52        3606                         MICROBIOLOGY
# 53    54        3601                 BIOCHEMICAL SCIENCES
# 54    55        3602                               BOTANY
# 59    60        1301                ENVIRONMENTAL SCIENCE
# 63    64        3608                           PHYSIOLOGY
# 64    65        3611                         NEUROSCIENCE
# 68    69        3699                MISCELLANEOUS BIOLOGY
# 70    71        3600                              BIOLOGY
# 71    72        3604                              ECOLOGY
# 75    76        3609                              ZOOLOGY
#
#             Major_category   Total     Men   Women  ShareWomen  Median
# ...

# %%
df[(df['Major_category'] == 'Biology & Life Science') | (df['Major_category'] == 'Health')]
# Out:
#     Rank  Major_code                                              Major  \
# 26    27        6107                                            NURSING
# 35    36        3607                                       PHARMACOLOGY
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 42    43        4006                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 47    48        3605                                           GENETICS
# 48    49        3603                                  MOLECULAR BIOLOGY
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 51    52        3606                                       MICROBIOLOGY
# 53    54        3601                               BIOCHEMICAL SCIENCES
# 54    55        3602                                             BOTANY
# 58    59        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# ...

# %%
df[df['Major_category'].isin(['Health', 'Biology & Life Science'])]
# Out:
#     Rank  Major_code                                              Major  \
# 26    27        6107                                            NURSING
# 35    36        3607                                       PHARMACOLOGY
# 36    37        6105                   MEDICAL TECHNOLOGIES TECHNICIANS
# 40    41        6104                         MEDICAL ASSISTING SERVICES
# 42    43        4006                COGNITIVE SCIENCE AND BIOPSYCHOLOGY
# 47    48        3605                                           GENETICS
# 48    49        3603                                  MOLECULAR BIOLOGY
# 49    50        6108  PHARMACY PHARMACEUTICAL SCIENCES AND ADMINISTR...
# 51    52        3606                                       MICROBIOLOGY
# 53    54        3601                               BIOCHEMICAL SCIENCES
# 54    55        3602                                             BOTANY
# 58    59        6199           MISCELLANEOUS HEALTH MEDICAL PROFESSIONS
# ...

# %%
#6
import seaborn as sns

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.shape
# Out:
# (150, 5)

# %%
len(df)
# Out:
# 150

# %%
df.species.value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
df.mean()
# Out:
# C:\Users\Arslan\AppData\Local\Temp\ipykernel_5524\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# sepal_length    5.843333
# sepal_width     3.057333
# petal_length    3.758000
# petal_width     1.199333
# dtype: float64

# %%
df.sepal_length.sum()
# Out:
# 876.5

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.drop('sepal_length', axis = 1)
# Out:
#      sepal_width  petal_length  petal_width    species
# 0            3.5           1.4          0.2     setosa
# 1            3.0           1.4          0.2     setosa
# 2            3.2           1.3          0.2     setosa
# 3            3.1           1.5          0.2     setosa
# 4            3.6           1.4          0.2     setosa
# ..           ...           ...          ...        ...
# 145          3.0           5.2          2.3  virginica
# 146          2.5           5.0          1.9  virginica
# 147          3.0           5.2          2.0  virginica
# 148          3.4           5.4          2.3  virginica
# 149          3.0           5.1          1.8  virginica
#
# [150 rows x 4 columns]

# %%
df = pd.DataFrame(np.arange(12).reshape(3,4),
                  columns = ['A', 'B', 'C', 'D'])
df
# Out:
#    A  B   C   D
# 0  0  1   2   3
# 1  4  5   6   7
# 2  8  9  10  11

# %%
df.drop(['B', 'C'], axis = 1)
# Out:
#    A   D
# 0  0   3
# 1  4   7
# 2  8  11

# %%
#7
df = df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/college-majors/women-stem.csv')
df.head()
# Out:
#    Rank  Major_code                                      Major Major_category  \
# 0     1        2419                      PETROLEUM ENGINEERING    Engineering
# 1     2        2416             MINING AND MINERAL ENGINEERING    Engineering
# 2     3        2415                  METALLURGICAL ENGINEERING    Engineering
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING    Engineering
# 4     5        2418                        NUCLEAR ENGINEERING    Engineering
#
#    Total   Men  Women  ShareWomen  Median
# 0   2339  2057    282    0.120564  110000
# 1    756   679     77    0.101852   75000
# 2    856   725    131    0.153037   73000
# 3   1258  1123    135    0.107313   70000
# 4   2573  2200    373    0.144967   65000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  76 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df.describe()
# Out:
#             Rank   Major_code          Total            Men          Women  \
# count  76.000000    76.000000      76.000000      76.000000      76.000000
# mean   38.500000  3580.026316   25515.289474   12800.763158   12714.526316
# std    22.083176  1437.455038   43998.008553   21307.554101   29056.014723
# min     1.000000  1301.000000     609.000000     488.000000      77.000000
# 25%    19.750000  2409.750000    3782.000000    2047.750000    1227.500000
# 50%    38.500000  3601.500000   11047.500000    4583.000000    5217.500000
# 75%    57.250000  5002.250000   27509.250000   11686.500000   12463.500000
# max    76.000000  6199.000000  280709.000000  111762.000000  187621.000000
#
#        ShareWomen         Median
# count   76.000000      76.000000
# mean     0.436929   46118.421053
# std      0.232176   13187.223216
# min      0.077453   26000.000000
# 25%      0.247918   36150.000000
# 50%      0.405868   44350.000000
# 75%      0.591803   52250.000000
# ...

# %%
df.Major_code.describe()
# Out:
# count      76.000000
# mean     3580.026316
# std      1437.455038
# min      1301.000000
# 25%      2409.750000
# 50%      3601.500000
# 75%      5002.250000
# max      6199.000000
# Name: Major_code, dtype: float64

# %%
df.Major_category.value_counts()
# Out:
# Engineering                29
# Biology & Life Science     14
# Health                     12
# Computers & Mathematics    11
# Physical Sciences          10
# Name: Major_category, dtype: int64

# %%
df.Major_category.value_counts(normalize=True)
#yüzdelikleri
# Out:
# Engineering                0.381579
# Biology & Life Science     0.184211
# Health                     0.157895
# Computers & Mathematics    0.144737
# Physical Sciences          0.131579
# Name: Major_category, dtype: float64

# %%
df.ShareWomen.mean()
# Out:
# 0.43692924057894733

# %%
df.ShareWomen.loc[df.Major_category == 'Engineering'].mean()
# Out:
# 0.23888867596551724

# %%
df.Major_category.unique()
# Out:
# array(['Engineering', 'Physical Sciences', 'Computers & Mathematics',
#        'Health', 'Biology & Life Science'], dtype=object)

# %%
df.Major_category.unique().tolist()
# Out:
# ['Engineering',
#  'Physical Sciences',
#  'Computers & Mathematics',
#  'Health',
#  'Biology & Life Science']

# %%
df.columns
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Major_category', 'Total', 'Men',
#        'Women', 'ShareWomen', 'Median'],
#       dtype='object')

# %%
import numpy as np
df.iloc[50:55, 3] = np.NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76 entries, 0 to 75
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Rank            76 non-null     int64
#  1   Major_code      76 non-null     int64
#  2   Major           76 non-null     object
#  3   Major_category  71 non-null     object
#  4   Total           76 non-null     int64
#  5   Men             76 non-null     int64
#  6   Women           76 non-null     int64
#  7   ShareWomen      76 non-null     float64
#  8   Median          76 non-null     int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 5.5+ KB

# %%
df.isnull().sum()
# Out:
# Rank              0
# Major_code        0
# Major             0
# Major_category    5
# Total             0
# Men               0
# Women             0
# ShareWomen        0
# Median            0
# dtype: int64

# %%
len(df)
# Out:
# 76

# %%
len(df.Women)
# Out:
# 76

# %%
len(df.Major_category)
#null degerleri de sayar
# Out:
# 76

# %% [markdown]
# ### Let's Pratice

# %%
import pandas as pd
import numpy as np

data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'city' :    [ 'Gurgaon', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai', 'Delhi', 'Mumbai'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})

data
# Out:
#    age section     city gender favourite_color
# 0   10       A  Gurgaon      M             red
# 1   22       B    Delhi      F            blue
# 2   13       C   Mumbai      F          yellow
# 3   21       D    Delhi      M            pink
# 4   12       E   Mumbai      M           black
# 5   11       F    Delhi      M           green
# 6   17       G   Mumbai      F             red

# %%
data['new'] = data['city'].str[:2]

# %%
data
# Out:
#    age section     city gender favourite_color new
# 0   10       A  Gurgaon      M             red  Gu
# 1   22       B    Delhi      F            blue  De
# 2   13       C   Mumbai      F          yellow  Mu
# 3   21       D    Delhi      M            pink  De
# 4   12       E   Mumbai      M           black  Mu
# 5   11       F    Delhi      M           green  De
# 6   17       G   Mumbai      F             red  Mu

# %%
data.set_index('section', inplace=True)
data
# Out:
#          age     city gender favourite_color new
# section
# A         10  Gurgaon      M             red  Gu
# B         22    Delhi      F            blue  De
# C         13   Mumbai      F          yellow  Mu
# D         21    Delhi      M            pink  De
# E         12   Mumbai      M           black  Mu
# F         11    Delhi      M           green  De
# G         17   Mumbai      F             red  Mu

# %%
data.iloc[:,2]
# Out:
# section
# A    M
# B    F
# C    F
# D    M
# E    M
# F    M
# G    F
# Name: gender, dtype: object

# %% [markdown]
# ## Check Yourself-3

# %%
data = pd.DataFrame({
    'age' :     [ 10, 22, 13, 21, 12, 11, 17],
    'section' : [ 'A', 'B', 'C', 'D', 'E', 'F', 'G'],
    'country' : [ 'USA', 'GBR', 'TUR', 'NLD', 'BEL', 'DEU', 'FRA'],
    'gender' :  [ 'M', 'F', 'F', 'M', 'M', 'M', 'F'],
    'favourite_color' : [ 'red', 'blue', 'yellow', 'pink', 'black', 'green', 'red']
})
data.set_index('section', inplace=True)
data
# Out:
#          age country gender favourite_color
# section
# A         10     USA      M             red
# B         22     GBR      F            blue
# C         13     TUR      F          yellow
# D         21     NLD      M            pink
# E         12     BEL      M           black
# F         11     DEU      M           green
# G         17     FRA      F             red

# %%
data[data['age']>15]
# Out:
#          age country gender favourite_color
# section
# B         22     GBR      F            blue
# D         21     NLD      M            pink
# G         17     FRA      F             red

# %%
data[data['age']>15]['country']
# Out:
# section
# B    GBR
# D    NLD
# G    FRA
# Name: country, dtype: object

# %%
data[(data['age']>15) & (data['favourite_color'] == 'red')]
# Out:
#          age country gender favourite_color
# section
# G         17     FRA      F             red

# %%
outside = ['A1','A1','A1','A2','A2','A2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)
np.random.seed(101)
data = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['X','Y'])
data
# Out:
#              X         Y
# A1 1  2.706850  0.628133
#    2  0.907969  0.503826
#    3  0.651118 -0.319318
# A2 1 -0.848077  0.605965
#    2 -2.018168  0.740122
#    3  0.528813 -0.589001

# %%
data['Y']
# Out:
# A1  1    0.628133
#     2    0.503826
#     3   -0.319318
# A2  1    0.605965
#     2    0.740122
#     3   -0.589001
# Name: Y, dtype: float64

# %%
data.loc['A1','X']
# Out:
# 1    2.706850
# 2    0.907969
# 3    0.651118
# Name: X, dtype: float64

# %%
data.loc['A1'].loc[1,'Y']
# Out:
# 0.6281327087844596
