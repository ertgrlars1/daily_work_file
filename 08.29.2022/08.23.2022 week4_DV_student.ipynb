# %% [markdown]
# # You will use mpg, tips, iris and titanic dataset for the following exercises.

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["figure.figsize"] = (6,4)
plt.rcParams['figure.dpi'] = 70
import warnings
warnings.filterwarnings("ignore")

# %%
iris=sns.load_dataset('iris')
mpg=sns.load_dataset('mpg')
tips = sns.load_dataset('tips')
titanic=sns.load_dataset('titanic')

# %% [markdown]
# # barplot and countplot

# %%
labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

# %% [markdown]
# # Instruction 1: Make a dataframe

# %%
df = pd.DataFrame({"labels": labels, "men_means" : men_means, "women_means" : women_means})
df
# Out:
#   labels  men_means  women_means
# 0     G1         20           25
# 1     G2         34           32
# 2     G3         30           34
# 3     G4         35           20
# 4     G5         27           25

# %%
# Out:
#   labels  men_means  women_means
# 0     G1         20           25
# 1     G2         34           32
# 2     G3         30           34
# 3     G4         35           20
# 4     G5         27           25

# %% [markdown]
# # Instruction 2: Make a bar plot with matplotlib

# %%
fig, ax = plt.subplots()
plt.bar(df.labels, df.men_means);

# %% [markdown]
# # Instruction 3: Make a barplot with seaborn

# %%
sns.barplot(df.labels, df.men_means)
# Out:
# <AxesSubplot:xlabel='labels', ylabel='men_means'>

# %%
 # method 1

# %%
sns.catplot(kind = "bar", x = "labels", y = "men_means", data = df, estimator=np.mean);

# %%
 #method2

# %% [markdown]
# # Instruction 4: Order the plot

# %%
sns.catplot(kind = "bar", x = "labels", y = "men_means", data = df.sort_values(by = "men_means"), estimator=np.mean)

# %%
#order
# method 1

# %%
df.sort_values(by = "men_means").labels
# Out:
# 0    G1
# 4    G5
# 2    G3
# 1    G2
# 3    G4
# Name: labels, dtype: object

# %%
# Out:
# 0    G1
# 4    G5
# 2    G3
# 1    G2
# 3    G4
# Name: labels, dtype: object

# %%
sns.barplot(x = "labels", y = "men_means", data = df.sort_values(by = "men_means"));

# %%
#auto order (method2)

# %%
sns.barplot(x = "labels", y = "men_means", data = df.sort_values(by = "men_means", ascending=False));

# %%
# auto order

# %% [markdown]
# # Barplot (actual)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.shape
# Out:
# (244, 7)

# %%
# Out:
# (244, 7)

# %% [markdown]
# # Instruction 5: Plot the avg total bill with seaborn

# %%
sns.barplot(x = tips.sex, y = tips.total_bill);

# %%
# get the mean of total bill according to sex
tips.groupby("sex")["total_bill"].mean()
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %%
# Out:
# sex
# Male      20.744076
# Female    18.056897
# Name: total_bill, dtype: float64

# %% [markdown]
# # Instruction 6: Show mean of total bill again but this time divide smokers/none smokers

# %%
# show the top 5 records
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# draw the plot below
sns.barplot( x= "sex", y="total_bill", hue="smoker",  data=tips);

# %% [markdown]
# # Instruction-7: Compare the avg tip in each day

# %%
sns.barplot( x= "day", y="tip",  data=tips);

# %% [markdown]
# # Instruction-8: Compare the avg horsepower for each cylinder type

# %%
sns.barplot( x= "cylinders", y="horsepower", data=mpg);

# %% [markdown]
# ## countplot

# %%
# count the car by model year
sns.countplot(x="model_year", data=mpg);

# %%
# count the car by origin
sns.countplot( x= "origin",  data=mpg);

# %% [markdown]
# # Instruction-9: Draw the below plots

# %%
# show the boxplot of total bill
sns.boxplot(y="total_bill", data=tips);

# %%
# split by day
sns.boxplot(y="total_bill", x="day", data=tips);

# %%
# split by smoker
sns.boxplot(y="total_bill", x="day", hue="smoker",data=tips);

# %%
# draw the plot and make comment about the swarm plot (Titanic)
sns.swarmplot(y="age", x="class", hue="survived", data=titanic);
