# %%
import pandas as pd
import numpy as np
from scipy import stats

# %%
df0 = pd.read_csv('car_ad.csv', encoding_errors = 'ignore')
df0
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
df = df0.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9576 entries, 0 to 9575
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           9576 non-null   object
#  1   price         9576 non-null   float64
#  2   body          9576 non-null   object
#  3   mileage       9576 non-null   int64
#  4   engV          9142 non-null   float64
#  5   engType       9576 non-null   object
#  6   registration  9576 non-null   object
#  7   year          9576 non-null   int64
#  8   model         9570 non-null   object
#  9   drive         9065 non-null   object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 748.2+ KB

# %%
df.isnull().sum()
# Out:
# car               0
# price             0
# body              0
# mileage           0
# engV            434
# engType           0
# registration      0
# year              0
# model             6
# drive           511
# dtype: int64

# %%
df.isnull().all(axis = 1).sum()
# hepsi null olan sutun yok
# Out:
# 0

# %%
df.groupby('body').agg({'year' : np.mean, 'engV' : np.mean})
# Out:
#                   year      engV
# body
# crossover  2009.554857  3.177341
# hatch      2006.507188  1.839513
# other      2006.633652  2.956620
# sedan      2004.988481  2.634003
# vagon      2005.523546  2.252536
# van        2007.252622  2.586078

# %%
df.groupby('body').filter(lambda x : x['engV'].mean() < 2.3)
# Out:
#                 car    price   body  mileage  engV engType registration  year  \
# 4     Mercedes-Benz  33000.0  vagon       91   NaN   Other          yes  2013
# 7           Renault  10500.0  vagon      185   1.5  Diesel          yes  2011
# 30           Nissan  13980.0  hatch       31   NaN   Other          yes  2013
# 31           Nissan  17300.0  hatch       24   NaN   Other          yes  2013
# 33             Audi   2600.0  vagon      273   2.5  Diesel           no  1999
# ...             ...      ...    ...      ...   ...     ...          ...   ...
# 9558      Chevrolet   5600.0  hatch      159   1.6  Petrol          yes  2008
# 9563          Skoda   6100.0  vagon       84   1.2  Petrol          yes  2007
# 9565  Mercedes-Benz   8900.0  hatch      155   1.5  Petrol          yes  2005
# 9568  Mercedes-Benz   5000.0  vagon      248   2.0     Gas          yes  1996
# 9572     Volkswagen   2200.0  vagon      150   1.6  Petrol          yes  1986
#
#           model  drive
# ...

# %%
df.groupby('body')[['price', 'mileage', 'engV', 'year']].transform(lambda x : (x.mean())).iloc[[30, 31], :]
# Out:
#           price     mileage      engV         year
# 30  8479.313508  112.702077  1.839513  2006.507188
# 31  8479.313508  112.702077  1.839513  2006.507188

# %%
df.groupby('body').apply('mean')
# Out:
#                   price     mileage      engV         year
# body
# crossover  29635.720586  100.293378  3.177341  2009.554857
# hatch       8479.313508  112.702077  1.839513  2006.507188
# other      19287.914249  135.378282  2.956620  2006.633652
# sedan      12151.912140  149.293747  2.634003  2004.988481
# vagon       8681.033847  174.757618  2.252536  2005.523546
# van        10519.914180  187.978074  2.586078  2007.252622

# %%
df
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 4     Mercedes-Benz  33000.0      vagon       91   NaN   Other          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
df[df.engV.isnull()]
# Out:
#                 car      price   body  mileage  engV engType registration  \
# 4     Mercedes-Benz  33000.000  vagon       91   NaN   Other          yes
# 13              BMW   4700.000  sedan      200   NaN  Petrol          yes
# 30           Nissan  13980.000  hatch       31   NaN   Other          yes
# 31           Nissan  17300.000  hatch       24   NaN   Other          yes
# 37             Audi   2850.000  sedan      260   NaN   Other           no
# ...             ...        ...    ...      ...   ...     ...          ...
# 9470       Chrysler      0.000  vagon      198   NaN  Petrol          yes
# 9480        Renault   8100.000    van      135   NaN  Diesel          yes
# 9515        Renault   5000.000  vagon      150   NaN   Other          yes
# 9546            VAZ    907.725  sedan        1   NaN   Other          yes
# 9566            UAZ    850.000    van      255   NaN   Other          yes
#
#       year       model  drive
# 4     2013     E-Class    NaN
# ...

# %%
df[df.price == 0]
# Out:
#                 car  price       body  mileage  engV engType registration  \
# 20       Land Rover    0.0  crossover        0   4.4  Diesel          yes
# 53    Mercedes-Benz    0.0  crossover        0   3.0  Diesel          yes
# 70    Mercedes-Benz    0.0  crossover        0   3.0  Diesel          yes
# 71           Toyota    0.0  crossover        0   4.5  Diesel          yes
# 90          Porsche    0.0      sedan       22   4.8  Petrol          yes
# ...             ...    ...        ...      ...   ...     ...          ...
# 9019         Toyota    0.0      hatch       76   1.0  Petrol          yes
# 9025  Mercedes-Benz    0.0  crossover        1   3.0  Petrol          yes
# 9036           Ford    0.0      other        1   5.0  Petrol          yes
# 9442        Renault    0.0      vagon      137   1.9  Diesel          yes
# 9470       Chrysler    0.0      vagon      198   NaN  Petrol          yes
#
#       year             model  drive
# 20    2016       Range Rover   full
# ...

# %%
df[df.drive.isnull()]
# Out:
#                 car    price   body  mileage   engV engType registration  \
# 4     Mercedes-Benz  33000.0  vagon       91    NaN   Other          yes
# 37             Audi   2850.0  sedan      260    NaN   Other           no
# 44              BMW  39333.0  sedan        6   2.00  Petrol          yes
# 52    Mercedes-Benz  31500.0  sedan      123   2.20  Diesel          yes
# 103      Volkswagen  10000.0    van      231   1.90  Diesel          yes
# ...             ...      ...    ...      ...    ...     ...          ...
# 9445         Nissan   5000.0  sedan      260   3.00     Gas          yes
# 9450            VAZ    750.0  sedan      123   1.20  Petrol          yes
# 9469        Renault   5650.0  hatch      175  99.99   Other          yes
# 9537     Volkswagen  11500.0  other       51   1.60  Petrol          yes
# 9566            UAZ    850.0    van      255    NaN   Other          yes
#
#       year               model drive
# 4     2013             E-Class   NaN
# ...

# %%
df[df.engType == 'Other']
# Out:
#                 car      price   body  mileage   engV engType registration  \
# 4     Mercedes-Benz  33000.000  vagon       91    NaN   Other          yes
# 30           Nissan  13980.000  hatch       31    NaN   Other          yes
# 31           Nissan  17300.000  hatch       24    NaN   Other          yes
# 37             Audi   2850.000  sedan      260    NaN   Other           no
# 41           Nissan  13275.000  hatch       12    NaN   Other          yes
# ...             ...        ...    ...      ...    ...     ...          ...
# 9425         Nissan  14999.000  hatch       21    NaN   Other          yes
# 9469        Renault   5650.000  hatch      175  99.99   Other          yes
# 9515        Renault   5000.000  vagon      150    NaN   Other          yes
# 9546            VAZ    907.725  sedan        1    NaN   Other          yes
# 9566            UAZ    850.000    van      255    NaN   Other          yes
#
#       year     model  drive
# 4     2013   E-Class    NaN
# ...

# %%
df.price.replace(0, np.nan, inplace = True)
df.price.isnull().sum()
# Out:
# 267

# %%
df.engType.replace('Other', np.nan, inplace = True)
df.engType.isnull().sum()
# Out:
# 462

# %%
df.year.unique()
# Out:
# array([2010, 2011, 2008, 2012, 2013, 2003, 2016, 1996, 2006, 2007, 2014,
#        2015, 1999, 2002, 1997, 2000, 2009, 1998, 2001, 2005, 2004, 1987,
#        1994, 1989, 1992, 1993, 1995, 1986, 1991, 1990, 1981, 1978, 1988,
#        1961, 1985, 1983, 1974, 1971, 1979, 1982, 1958, 1962, 1963, 1977,
#        1980, 1959, 1984, 1973, 1953, 1970, 1976, 1972, 1964, 1969, 1968,
#        1975], dtype=int64)

# %%
df.drive.unique()
# Out:
# array(['full', 'rear', 'front', nan], dtype=object)

# %%
df.car.unique()
# Out:
# array(['Ford', 'Mercedes-Benz', 'Nissan', 'Honda', 'Renault', 'BMW',
#        'Land Rover', 'Volkswagen', 'Audi', 'Chrysler', 'Jaguar',
#        'Mitsubishi', 'Kia', 'Porsche', 'Toyota', 'Hyundai', 'Opel',
#        'Chevrolet', 'Skoda', 'Daewoo', 'Mazda', 'Lexus', 'Infiniti',
#        'Tesla', 'Subaru', 'VAZ', 'Alfa Romeo', 'Smart', 'Peugeot',
#        'Suzuki', 'Chery', 'Bentley', 'Volvo', 'SsangYong', 'Fiat', 'ZAZ',
#        'Citroen', 'Dodge', 'Jeep', 'Great Wall', 'Seat', 'MINI', 'Dacia',
#        'Hummer', 'Geely', 'Maserati', 'BYD', 'Cadillac', 'Acura',
#        'Aston Martin', 'Rover', 'GAZ', 'GMC', 'Lincoln', 'UAZ',
#        'Moskvich-AZLK', 'FAW', 'Rolls-Royce', 'TATA', 'ZX', 'Lifan',
#        'Mercury', 'Groz', 'Moskvich-Izh', 'Saab', 'Lancia', 'Aro',
#        'Ferrari', 'Isuzu', 'Bogdan', 'Dadi', 'Other-Retro', 'MG',
#        'Samand', 'JAC', 'Samsung', 'Lamborghini', 'Daihatsu', 'Hafei',
#        'SMA', 'Fisker', 'Changan', 'Barkas', 'Huanghai', 'Wartburg',
# ...

# %%
df.body.unique()
# Out:
# array(['crossover', 'sedan', 'other', 'van', 'vagon', 'hatch'],
#       dtype=object)

# %%
df.price.dtype
# Out:
# dtype('float64')

# %%
df.dropna(how = 'any')
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 5            Nissan  16600.0  crossover       83   2.0  Petrol          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
df.shape
# Out:
# (9576, 10)

# %%
df.dropna(thresh = 10, axis = 0)
# Out:
#                 car    price       body  mileage  engV engType registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas          yes
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas          yes
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol          yes
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel          yes
# 5            Nissan  16600.0  crossover       83   2.0  Petrol          yes
# ...             ...      ...        ...      ...   ...     ...          ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas          yes
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol          yes
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol          yes
# 9574          Lexus  16999.0      sedan      150   3.5     Gas          yes
# 9575           Audi  22500.0      other       71   3.6  Petrol          yes
#
#       year      model  drive
# ...

# %%
df.dropna(axis = 1, how = 'any')
# bu sutunlarda hiç null değer yok
# Out:
#                 car       body  mileage registration  year
# 0              Ford  crossover       68          yes  2010
# 1     Mercedes-Benz      sedan      173          yes  2011
# 2     Mercedes-Benz      other      135          yes  2008
# 3     Mercedes-Benz        van      162          yes  2012
# 4     Mercedes-Benz      vagon       91          yes  2013
# ...             ...        ...      ...          ...   ...
# 9571        Hyundai  crossover      140          yes  2011
# 9572     Volkswagen      vagon      150          yes  1986
# 9573  Mercedes-Benz  crossover      180          yes  2008
# 9574          Lexus      sedan      150          yes  2008
# 9575           Audi      other       71          yes  2007
#
# [9576 rows x 5 columns]

# %%
df.registration.unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df.registration
# Out:
# 0       yes
# 1       yes
# 2       yes
# 3       yes
# 4       yes
#        ...
# 9571    yes
# 9572    yes
# 9573    yes
# 9574    yes
# 9575    yes
# Name: registration, Length: 9576, dtype: object

# %%
df.registration.map({'yes' : 1, 'no' : 0})
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 9571    1
# 9572    1
# 9573    1
# 9574    1
# 9575    1
# Name: registration, Length: 9576, dtype: int64

# %%
df.registration = df.registration.map({'yes' : 1, 'no' : 0})
df.head()
# Out:
#              car    price       body  mileage  engV engType  registration  \
# 0           Ford  15500.0  crossover       68   2.5     Gas             1
# 1  Mercedes-Benz  20500.0      sedan      173   1.8     Gas             1
# 2  Mercedes-Benz  35000.0      other      135   5.5  Petrol             1
# 3  Mercedes-Benz  17800.0        van      162   1.8  Diesel             1
# 4  Mercedes-Benz  33000.0      vagon       91   NaN     NaN             1
#
#    year    model  drive
# 0  2010     Kuga   full
# 1  2011  E-Class   rear
# 2  2008   CL 550   rear
# 3  2012    B 180  front
# 4  2013  E-Class    NaN

# %%
df.fillna('a')
# Out:
#                 car    price       body  mileage engV engType  registration  \
# 0              Ford  15500.0  crossover       68  2.5     Gas             1
# 1     Mercedes-Benz  20500.0      sedan      173  1.8     Gas             1
# 2     Mercedes-Benz  35000.0      other      135  5.5  Petrol             1
# 3     Mercedes-Benz  17800.0        van      162  1.8  Diesel             1
# 4     Mercedes-Benz  33000.0      vagon       91    a       a             1
# ...             ...      ...        ...      ...  ...     ...           ...
# 9571        Hyundai  14500.0  crossover      140  2.0     Gas             1
# 9572     Volkswagen   2200.0      vagon      150  1.6  Petrol             1
# 9573  Mercedes-Benz  18500.0  crossover      180  3.5  Petrol             1
# 9574          Lexus  16999.0      sedan      150  3.5     Gas             1
# 9575           Audi  22500.0      other       71  3.6  Petrol             1
#
#       year      model  drive
# ...

# %%
df.engV.fillna(df.engV.mean())
# Out:
# 0       2.500000
# 1       1.800000
# 2       5.500000
# 3       1.800000
# 4       2.646344
#           ...
# 9571    2.000000
# 9572    1.600000
# 9573    3.500000
# 9574    3.500000
# 9575    3.600000
# Name: engV, Length: 9576, dtype: float64

# %%
df
# Out:
#                 car    price       body  mileage  engV engType  registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas             1
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas             1
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol             1
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel             1
# 4     Mercedes-Benz  33000.0      vagon       91   NaN     NaN             1
# ...             ...      ...        ...      ...   ...     ...           ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas             1
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol             1
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol             1
# 9574          Lexus  16999.0      sedan      150   3.5     Gas             1
# 9575           Audi  22500.0      other       71   3.6  Petrol             1
#
#       year      model  drive
# ...

# %%
df.engType.mode()
# Out:
# 0    Petrol
# Name: engType, dtype: object

# %%
df.engType.fillna(df.engType.mode()[0])
# Out:
# 0          Gas
# 1          Gas
# 2       Petrol
# 3       Diesel
# 4       Petrol
#          ...
# 9571       Gas
# 9572    Petrol
# 9573    Petrol
# 9574       Gas
# 9575    Petrol
# Name: engType, Length: 9576, dtype: object

# %%
df
# Out:
#                 car    price       body  mileage  engV engType  registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas             1
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas             1
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol             1
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel             1
# 4     Mercedes-Benz  33000.0      vagon       91   NaN     NaN             1
# ...             ...      ...        ...      ...   ...     ...           ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas             1
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol             1
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol             1
# 9574          Lexus  16999.0      sedan      150   3.5     Gas             1
# 9575           Audi  22500.0      other       71   3.6  Petrol             1
#
#       year      model  drive
# ...

# %%
df[df.model == 'E-Class']
# Out:
#                 car    price   body  mileage  engV engType  registration  \
# 1     Mercedes-Benz  20500.0  sedan      173   1.8     Gas             1
# 4     Mercedes-Benz  33000.0  vagon       91   NaN     NaN             1
# 8     Mercedes-Benz  21500.0  sedan      146   1.8     Gas             1
# 9     Mercedes-Benz  22700.0  sedan      125   2.2  Diesel             1
# 11    Mercedes-Benz  20400.0  sedan      190   1.8     Gas             1
# ...             ...      ...    ...      ...   ...     ...           ...
# 9275  Mercedes-Benz  23900.0  sedan      124   1.8  Petrol             1
# 9467  Mercedes-Benz  10900.0  sedan      217   3.2  Diesel             1
# 9512  Mercedes-Benz   5000.0  sedan      382   2.0  Petrol             1
# 9535  Mercedes-Benz   2300.0  sedan      300   3.0  Diesel             1
# 9568  Mercedes-Benz   5000.0  vagon      248   2.0     Gas             1
#
#       year    model drive
# 1     2011  E-Class  rear
# 4     2013  E-Class   NaN
# ...

# %%
df.loc[df.model == 'E-Class', 'drive']
# Out:
# 1       rear
# 4        NaN
# 8       rear
# 9       rear
# 11      rear
#         ...
# 9275    rear
# 9467    rear
# 9512    rear
# 9535    rear
# 9568    rear
# Name: drive, Length: 199, dtype: object

# %%
df.loc[df.model == 'E-Class', 'drive'] = df.loc[df.model == 'E-Class', 'drive'].fillna(df.loc[df.model == 'E-Class', 'drive'].mode()[0])
df.loc[df.model == 'E-Class', 'drive']
# Out:
# 1       rear
# 4       rear
# 8       rear
# 9       rear
# 11      rear
#         ...
# 9275    rear
# 9467    rear
# 9512    rear
# 9535    rear
# 9568    rear
# Name: drive, Length: 199, dtype: object

# %%
df
# Out:
#                 car    price       body  mileage  engV engType  registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas             1
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas             1
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol             1
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel             1
# 4     Mercedes-Benz  33000.0      vagon       91   NaN     NaN             1
# ...             ...      ...        ...      ...   ...     ...           ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas             1
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol             1
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol             1
# 9574          Lexus  16999.0      sedan      150   3.5     Gas             1
# 9575           Audi  22500.0      other       71   3.6  Petrol             1
#
#       year      model  drive
# ...

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz'), :]
# Out:
#                 car    price       body  mileage  engV engType  registration  \
# 9     Mercedes-Benz  22700.0      sedan      125   2.2  Diesel             1
# 88    Mercedes-Benz  16500.0      other      107   2.2  Diesel             1
# 549   Mercedes-Benz  44000.0      other       82   5.5  Petrol             1
# 602   Mercedes-Benz  39900.0  crossover      127   5.5  Petrol             1
# 702   Mercedes-Benz  69900.0      sedan       76   6.0  Petrol             1
# 740   Mercedes-Benz  32000.0  crossover       96   3.5  Petrol             1
# 834   Mercedes-Benz  22900.0      sedan      197   2.2  Diesel             1
# 1056  Mercedes-Benz  16300.0        van      175   2.2  Diesel             1
# 1565  Mercedes-Benz  23200.0      sedan       58   1.8  Petrol             1
# 1929  Mercedes-Benz  39900.0  crossover      126   5.5  Petrol             1
# 2103  Mercedes-Benz  69900.0      sedan       76   6.0  Petrol             1
# ...

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz'), :].isnull().sum()
# Out:
# car             0
# price           0
# body            0
# mileage         0
# engV            2
# engType         0
# registration    0
# year            0
# model           0
# drive           3
# dtype: int64

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.drive.isnull()), :]
# Out:
#                 car    price       body  mileage  engV engType  registration  \
# 3096  Mercedes-Benz  23999.0      other      150   NaN  Diesel             1
# 7416  Mercedes-Benz  11800.0        van      148   2.2  Diesel             1
# 9021  Mercedes-Benz  29900.0  crossover       86   3.0     Gas             1
#
#       year    model drive
# 3096  2010   Vito .   NaN
# 7416  2010   Vito .   NaN
# 9021  2010  GLK 300   NaN

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), :]
# Out:
#                 car    price body  mileage  engV engType  registration  year  \
# 1056  Mercedes-Benz  16300.0  van      175   2.2  Diesel             1  2010
# 2508  Mercedes-Benz  11500.0  van      200   2.2  Diesel             1  2010
# 6903  Mercedes-Benz   9300.0  van      159   2.2  Diesel             1  2010
# 7416  Mercedes-Benz  11800.0  van      148   2.2  Diesel             1  2010
# 7837  Mercedes-Benz  18500.0  van      170   2.2  Diesel             1  2010
# 8552  Mercedes-Benz  17800.0  van      145   2.2  Diesel             1  2010
#
#        model drive
# 1056  Vito .  rear
# 2508  Vito .  rear
# 6903  Vito .  rear
# 7416  Vito .   NaN
# 7837  Vito .  rear
# 8552  Vito .  rear

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), 'drive']
# Out:
# 1056    rear
# 2508    rear
# 6903    rear
# 7416     NaN
# 7837    rear
# 8552    rear
# Name: drive, dtype: object

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), 'drive'].mode()[0]
# Out:
# 'rear'

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), 'drive'] = df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), 'drive'].fillna(df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), 'drive'].mode()[0])

# %%
df.loc[(df.year == 2010) & (df.car == 'Mercedes-Benz') & (df.body == 'van'), :]
# Out:
#                 car    price body  mileage  engV engType  registration  year  \
# 1056  Mercedes-Benz  16300.0  van      175   2.2  Diesel             1  2010
# 2508  Mercedes-Benz  11500.0  van      200   2.2  Diesel             1  2010
# 6903  Mercedes-Benz   9300.0  van      159   2.2  Diesel             1  2010
# 7416  Mercedes-Benz  11800.0  van      148   2.2  Diesel             1  2010
# 7837  Mercedes-Benz  18500.0  van      170   2.2  Diesel             1  2010
# 8552  Mercedes-Benz  17800.0  van      145   2.2  Diesel             1  2010
#
#        model drive
# 1056  Vito .  rear
# 2508  Vito .  rear
# 6903  Vito .  rear
# 7416  Vito .  rear
# 7837  Vito .  rear
# 8552  Vito .  rear

# %%
df
# Out:
#                 car    price       body  mileage  engV engType  registration  \
# 0              Ford  15500.0  crossover       68   2.5     Gas             1
# 1     Mercedes-Benz  20500.0      sedan      173   1.8     Gas             1
# 2     Mercedes-Benz  35000.0      other      135   5.5  Petrol             1
# 3     Mercedes-Benz  17800.0        van      162   1.8  Diesel             1
# 4     Mercedes-Benz  33000.0      vagon       91   NaN     NaN             1
# ...             ...      ...        ...      ...   ...     ...           ...
# 9571        Hyundai  14500.0  crossover      140   2.0     Gas             1
# 9572     Volkswagen   2200.0      vagon      150   1.6  Petrol             1
# 9573  Mercedes-Benz  18500.0  crossover      180   3.5  Petrol             1
# 9574          Lexus  16999.0      sedan      150   3.5     Gas             1
# 9575           Audi  22500.0      other       71   3.6  Petrol             1
#
#       year      model  drive
# ...

# %%
df[(df.car == 'Mercedes-Benz') & (df.year == 2013)]
# Out:
#                 car     price       body  mileage  engV engType  registration  \
# 4     Mercedes-Benz   33000.0      vagon       91   NaN     NaN             1
# 39    Mercedes-Benz  200000.0        van       19  3.50  Petrol             1
# 196   Mercedes-Benz   12500.0        van      167  2.20  Diesel             1
# 215   Mercedes-Benz       NaN      sedan       62  3.00  Diesel             1
# 293   Mercedes-Benz   55000.0  crossover       40  4.60  Petrol             1
# 550   Mercedes-Benz   12000.0        van      177   NaN  Diesel             1
# 615   Mercedes-Benz  140000.0  crossover       88  5.46  Petrol             1
# 1075  Mercedes-Benz   99000.0        van        5  1.60  Diesel             1
# 1584  Mercedes-Benz   29500.0      sedan       64  1.60  Petrol             1
# 1657  Mercedes-Benz   19600.0      vagon      127  1.80  Diesel             1
# 1722  Mercedes-Benz   28000.0      other       12  1.80  Petrol             1
# ...

# %%
df[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito .')]
# Out:
#                 car    price   body  mileage  engV engType  registration  \
# 196   Mercedes-Benz  12500.0    van      167   2.2  Diesel             1
# 550   Mercedes-Benz  12000.0    van      177   NaN  Diesel             1
# 1824  Mercedes-Benz  16800.0    van      116   2.2  Diesel             1
# 2057  Mercedes-Benz  16800.0    van      116   NaN     NaN             1
# 2199  Mercedes-Benz  12800.0  other      116   2.2  Diesel             1
# 2411  Mercedes-Benz  13600.0    van      172   2.2  Diesel             1
# 2467  Mercedes-Benz  13995.0    van      126   2.2  Diesel             1
# 2481  Mercedes-Benz  18000.0    van      147   2.2  Diesel             1
# 4311  Mercedes-Benz  13500.0    van       97   2.2  Diesel             1
# 8290  Mercedes-Benz  31500.0    van       95   2.2  Diesel             1
#
#       year   model drive
# 196   2013  Vito .  rear
# 550   2013  Vito .  rear
# 1824  2013  Vito .  full
# 2057  2013  Vito .   NaN
# 2199  2013  Vito .   NaN
# ...

# %%
df.model.replace('Vito .', 'Vito', inplace = True)

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), :]
# Out:
#                 car    price   body  mileage  engV engType  registration  \
# 196   Mercedes-Benz  12500.0    van      167   2.2  Diesel             1
# 550   Mercedes-Benz  12000.0    van      177   NaN  Diesel             1
# 1824  Mercedes-Benz  16800.0    van      116   2.2  Diesel             1
# 2057  Mercedes-Benz  16800.0    van      116   NaN     NaN             1
# 2199  Mercedes-Benz  12800.0  other      116   2.2  Diesel             1
# 2411  Mercedes-Benz  13600.0    van      172   2.2  Diesel             1
# 2467  Mercedes-Benz  13995.0    van      126   2.2  Diesel             1
# 2481  Mercedes-Benz  18000.0    van      147   2.2  Diesel             1
# 4311  Mercedes-Benz  13500.0    van       97   2.2  Diesel             1
# 8290  Mercedes-Benz  31500.0    van       95   2.2  Diesel             1
#
#       year model drive
# 196   2013  Vito  rear
# 550   2013  Vito  rear
# 1824  2013  Vito  full
# 2057  2013  Vito   NaN
# 2199  2013  Vito   NaN
# ...

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engV']
# Out:
# 196     2.2
# 550     NaN
# 1824    2.2
# 2057    NaN
# 2199    2.2
# 2411    2.2
# 2467    2.2
# 2481    2.2
# 4311    2.2
# 8290    2.2
# Name: engV, dtype: float64

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engV'].mode()[0]
# Out:
# 2.2

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engV'] = df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engV'].fillna(df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engV'].mode()[0])

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engType'] = df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engType'].fillna(df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'engType'].mode()[0])

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'drive'] = df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'drive'].fillna(df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'drive'].mode()[0])

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), :]
# Out:
#                 car    price   body  mileage  engV engType  registration  \
# 196   Mercedes-Benz  12500.0    van      167   2.2  Diesel             1
# 550   Mercedes-Benz  12000.0    van      177   2.2  Diesel             1
# 1824  Mercedes-Benz  16800.0    van      116   2.2  Diesel             1
# 2057  Mercedes-Benz  16800.0    van      116   2.2  Diesel             1
# 2199  Mercedes-Benz  12800.0  other      116   2.2  Diesel             1
# 2411  Mercedes-Benz  13600.0    van      172   2.2  Diesel             1
# 2467  Mercedes-Benz  13995.0    van      126   2.2  Diesel             1
# 2481  Mercedes-Benz  18000.0    van      147   2.2  Diesel             1
# 4311  Mercedes-Benz  13500.0    van       97   2.2  Diesel             1
# 8290  Mercedes-Benz  31500.0    van       95   2.2  Diesel             1
#
#       year model drive
# 196   2013  Vito  rear
# 550   2013  Vito  rear
# 1824  2013  Vito  full
# 2057  2013  Vito  rear
# 2199  2013  Vito  rear
# ...

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'body'] = df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), 'body'].replace('other', 'van')

# %%
df.loc[(df.car == 'Mercedes-Benz') & (df.year == 2013) & (df.model == 'Vito'), :]
# Out:
#                 car    price body  mileage  engV engType  registration  year  \
# 196   Mercedes-Benz  12500.0  van      167   2.2  Diesel             1  2013
# 550   Mercedes-Benz  12000.0  van      177   2.2  Diesel             1  2013
# 1824  Mercedes-Benz  16800.0  van      116   2.2  Diesel             1  2013
# 2057  Mercedes-Benz  16800.0  van      116   2.2  Diesel             1  2013
# 2199  Mercedes-Benz  12800.0  van      116   2.2  Diesel             1  2013
# 2411  Mercedes-Benz  13600.0  van      172   2.2  Diesel             1  2013
# 2467  Mercedes-Benz  13995.0  van      126   2.2  Diesel             1  2013
# 2481  Mercedes-Benz  18000.0  van      147   2.2  Diesel             1  2013
# 4311  Mercedes-Benz  13500.0  van       97   2.2  Diesel             1  2013
# 8290  Mercedes-Benz  31500.0  van       95   2.2  Diesel             1  2013
#
#      model drive
# 196   Vito  rear
# 550   Vito  rear
# 1824  Vito  full
# 2057  Vito  rear
# 2199  Vito  rear
# ...

# %%
df.isnull().sum()
# Out:
# car               0
# price           267
# body              0
# mileage           0
# engV            432
# engType         461
# registration      0
# year              0
# model             6
# drive           493
# dtype: int64

# %%
df.car.value_counts()
# Out:
# Volkswagen       936
# Mercedes-Benz    921
# BMW              694
# Toyota           541
# VAZ              489
#                 ...
# ZX                 1
# Other-Retro        1
# Mercury            1
# Maserati           1
# Buick              1
# Name: car, Length: 86, dtype: int64

# %%
df.loc[(df.car == 'Volkswagen') & (df.drive.isnull()), :].count()
# Out:
# car             57
# price           53
# body            57
# mileage         57
# engV            47
# engType         47
# registration    57
# year            57
# model           57
# drive            0
# dtype: int64

# %%
df.loc[((df.car == 'Volkswagen') & (df.year == 2013))]
# Out:
#              car    price       body  mileage  engV engType  registration  \
# 97    Volkswagen      NaN        van      165   2.0  Diesel             1
# 107   Volkswagen  33500.0  crossover       98   NaN  Petrol             1
# 138   Volkswagen  30000.0      sedan       67   2.0  Diesel             1
# 155   Volkswagen  14499.0        van      164   2.0  Diesel             1
# 162   Volkswagen  18900.0      other       45   2.0  Diesel             1
# ...          ...      ...        ...      ...   ...     ...           ...
# 8941  Volkswagen  21000.0      vagon       58   2.0  Diesel             1
# 9114  Volkswagen  10650.0      sedan       65   1.6  Petrol             1
# 9135  Volkswagen  14899.0        van      165   2.0  Diesel             1
# 9172  Volkswagen  17900.0      sedan       96   2.5  Petrol             1
# 9537  Volkswagen  11500.0      other       51   1.6  Petrol             1
#
#       year              model  drive
# 97    2013  T5 (Transporter)   front
# ...

# %%
df.loc[((df.car == 'Volkswagen') & (df.year == 2013) & (df.drive.isnull()))]
# Out:
#              car    price   body  mileage  engV engType  registration  year  \
# 512   Volkswagen  23000.0  sedan       75   2.0  Petrol             1  2013
# 3019  Volkswagen  20700.0  vagon       74   2.0  Diesel             1  2013
# 8849  Volkswagen   5000.0  sedan       81   NaN     NaN             0  2013
# 9135  Volkswagen  14899.0    van      165   2.0  Diesel             1  2013
# 9537  Volkswagen  11500.0  other       51   1.6  Petrol             1  2013
#
#           model drive
# 512   Passat CC   NaN
# 3019  Passat B7   NaN
# 8849  Passat B7   NaN
# 9135    Caddy .   NaN
# 9537       Polo   NaN
